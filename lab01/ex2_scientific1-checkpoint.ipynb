# %% [markdown]
# # ex2_scientific1

# %% [markdown]
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# Sinh ngẫu nhiên tọa độ tâm (x, y) của hình tròn, màu sắc và diện tích
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # Mảng diện tích cho N hình tròn với bán kính ngẫu nhiên từ 0 dến 15
# Out:
# CPU times: user 4 μs, sys: 1 μs, total: 5 μs
# Wall time: 8.58 μs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.00, 0.96]: 10 samples [[0.38598401 0.76033195 0.84510906 0.87967449 0.56570865 0.10479009
#  0.89769486 0.36656947 0.24627904 0.44767924]]
# + y: len=50, [0.03, 0.99]: 10 samples [[0.44456401 0.44899801 0.5359687  0.93857706 0.45681118 0.05815435
#  0.47110123 0.99157599 0.46319577 0.72023085]]
# + colors: len=50, [0.01, 1.00]: 10 samples [[0.88936891 0.80355178 0.37312845 0.46700841 0.85373299 0.05363929
#  0.24147989 0.11203624 0.71234223 0.2738211 ]]
# + area: len=50, [1.41, 690.99]: 10 samples [[355.45291258 246.38414774 129.92661669   1.755565   285.37968172
#  453.81145162  80.83195147 145.18090723 122.13394683 310.51474539]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=1.0)
plt.show()

# %%
# !jupyter nbconvert ex2_scientific1-checkpoint.ipynb --to html
# Out:
# [NbConvertApp] Converting notebook ex2_scientific1-checkpoint.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 338473 bytes to ex2_scientific1-checkpoint.html

# %% [markdown]
# # Kết thúc
